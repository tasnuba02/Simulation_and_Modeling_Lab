# %%
# ===============================
# Install reportlab (for PDF)
# ===============================
# !pip install reportlab

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
from reportlab.lib.pagesizes import A4
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer, Image
from reportlab.lib.styles import getSampleStyleSheet

# ===============================
# Student ID
# ===============================
student_id = "14"   # <-- change if needed
filename = f"{student_id}_Lab_Assignment_2.pdf"

# ===============================
# Dataset Generation (k = ID)
# ===============================
np.random.seed(14)  # reproducibility
data = 60 + np.random.randint(0, 15, size=12) + (14 % 5)

# Hypothesized mean
population_mean = 65

# One-sample t-test
t_stat, p_val = stats.ttest_1samp(data, population_mean)

# 95% CI
ci = stats.t.interval(
    0.95, df=len(data)-1,
    loc=np.mean(data),
    scale=stats.sem(data)
)

# Decision
alpha = 0.05
if p_val < alpha:
    conclusion = f"Reject H₀: The sample mean is significantly different from {population_mean}."
else:
    conclusion = f"Fail to Reject H₀: The sample mean is not significantly different from {population_mean}."

# ===============================
# Plot (for PDF)
# ===============================
plt.figure(figsize=(6,5))
plt.bar(1, np.mean(data), color="skyblue", label="Sample Mean")
plt.errorbar(1, np.mean(data), yerr=stats.sem(data), fmt='k', capsize=5)
plt.axhline(y=population_mean, color="r", linestyle="--", label="Hypothesized Mean (65)")
plt.title("One-Sample t-Test Visualization (ID=14)")
plt.xticks([1], ["Exam Scores"])
plt.ylabel("Mean Value")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)
plt.savefig("t_test_plot.png")
plt.close()

# ===============================
# Assignment Content
# ===============================
objective = """
Objective:
To clearly understand why we compare the p-value with α (alpha) and when we accept/reject the
null hypothesis (H0) or the alternative hypothesis (H1).
"""

partA = """
Part A: Easy Explanation

1. What is α (alpha)?
- Alpha is the cut-off line we set before testing.
- Example: If α = 0.05, we allow a 5% chance of being wrong.

2. What is the p-value?
- p-value is evidence from the data.
- It shows how likely our result is if H0 were true.
- Smaller p → stronger evidence against H0.

3. Why do we compare p-value with α?
- Because we need a decision rule.
- If p ≤ α → Reject H0 (accept H1).
- If p > α → Fail to reject H0.
"""

partB = """
Part B: Rule of the Game
🎯 If p-value ≤ α → H1 wins (reject H0).
🎯 If p-value > α → H0 wins (fail to reject H0).

Think of it like a race:
- α = finish line
- p-value = runner
- If runner crosses the line (≤ α) → H1 wins.
- If runner doesn’t cross (> α) → H0 stays.
"""

partC = """
Part C: Practice Questions

1) Suppose α = 0.05:
   (a) If p = 0.03 → H1 wins, because p < α.
   (b) If p = 0.08 → H0 wins, because p > α.

2) In my own words:
   - We need α because it controls our strictness in testing.
   - A very small p-value means the result is very unlikely under H0 → strong evidence against H0.

3) Example with α = 0.01:
   - Case 1: p = 0.007 → H1 wins (reject H0).
   - Case 2: p = 0.04 → H0 wins (fail to reject H0).
"""

partD = """
Part D: Mini Creative Task

Courtroom Analogy:
- H0 = person is innocent
- H1 = person is guilty
- p-value = strength of lawyer’s evidence
- α = judge’s strictness

If p ≤ α, the judge says: “Evidence strong enough → guilty (H1).”
If p > α, the judge says: “Not enough evidence → not guilty (H0 stays).”
This shows that failing to reject H0 does not prove innocence; it just means evidence wasn’t strong.
"""

results = f"""
Practical Results (using ID={student_id}):

Dataset: {list(data)}
Sample Mean = {np.mean(data):.2f}
Hypothesized Mean = {population_mean}
t-Statistic = {t_stat:.2f}
Degrees of Freedom = {len(data)-1}
p-Value = {p_val:.4f}
95% CI = [{ci[0]:.2f}, {ci[1]:.2f}]
Conclusion: {conclusion}
"""

# ===============================
# Build PDF
# ===============================
doc = SimpleDocTemplate(filename, pagesize=A4)
styles = getSampleStyleSheet()
content = []

content.append(Paragraph("Lab Assignment 2: Understanding p-value, α, and Hypothesis Testing", styles["Title"]))
content.append(Spacer(1, 12))

for section in [objective, partA, partB, partC, partD, results]:
    content.append(Paragraph(section.replace("\n","<br/>"), styles["Normal"]))
    content.append(Spacer(1, 12))

content.append(Paragraph("Visualization:", styles["Heading2"]))
content.append(Image("t_test_plot.png", width=350, height=300))

doc.build(content)

print(f"✅ PDF generated successfully: {filename}")
# Out:
# ...
# ✅ PDF generated successfully: 14_Lab_Assignment_2.pdf
